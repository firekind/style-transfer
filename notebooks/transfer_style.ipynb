# %%
import os
os.chdir("../")

# %%
from style_transfer.solver import transfer_style
import matplotlib.pyplot as plt

# %%
output = transfer_style(
    "images/content.jpg",
    "images/style.jpg",
    cuda=True,
    content_as_input=True,
    epochs=16,
    content_weight=1,
    style_weight=1e6,
    image_size=512
)
# Out:
# 16/16 [==============================] - 42s 3s/epoch - content loss: 24.9435 - style loss: 123832.9982

# %%
plt.figure(figsize=(10.4 , 8.8))
plt.imshow(output)
