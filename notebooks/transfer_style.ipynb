# %%
import os
os.chdir("../")

# %%
from style_transfer.solver import transfer_style
import matplotlib.pyplot as plt

# %%
output = transfer_style(
    "images/content.jpg",
    "images/style.jpg",
    cuda=True,
    content_as_input=True,
    epochs=16,
    content_weight=1,
    style_weight=1000000,
    image_size=512
)
# Out:
# 16/16 [==============================] - 50s 3s/epoch - content loss: 25.0302 - style loss: 0.1238

# %%
plt.figure(figsize=(10.4 , 8.8))
plt.imshow(output)
