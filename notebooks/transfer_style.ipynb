# %%
import os
os.chdir("../")

# %%
from style_transfer.solver import transfer_style
import matplotlib.pyplot as plt

# %%
output = transfer_style(
    "images/dancing.jpg",
    "images/picasso.jpg",
    cuda=True,
    content_as_input=True,
    epochs=16,
    content_weight=1,
    style_weight=1000000,
    image_size=512
)
# Out:
# 16/16 [==============================] - 39s 2s/epoch - content loss: 2.9148 - style loss: 2.1962e-05

# %%
plt.imshow(output)
